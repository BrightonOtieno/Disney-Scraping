# %%
import pandas as pd

# %%
# when you want  to read in the json data
import json
def load_data(title):
    with open(title,encoding='utf-8') as f:
        return json.load(f)

# %%
movie_info_list = load_data('disney_data_cleaned.json')# pass in title -> name of json file

# %%
# list of movie objects
movie_info_list
# Out:
# [{'title': 'Academy Award Review of',
#   'Production company': 'Walt Disney Productions',
#   'Release date': ['May 19, 1937'],
#   'Running time': '41 minutes (74 minutes 1966 release)',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$45.472'},
#  {'title': 'Snow White and the Seven Dwarfs',
#   'Directed by': ['David Hand (supervising)',
#    'William Cottrell',
#    'Wilfred Jackson',
#    'Larry Morey',
#    'Perce Pearce',
#    'Ben Sharpsteen'],
#   'Produced by': 'Walt Disney',
#   'Written by': ['Ted Sears',
#    'Richard Creedon',
#    'Otto Englander',
#    'Dick Rickard',
#    'Earl Hurd',
#    'Merrill De Maris',
#    'Dorothy Ann Blank',
#    'Webb Smith'],
#   'Based on': ['Snow White', 'by The', 'Brothers Grimm'],
#   'Starring': ['Adriana Caselotti',
#    'Lucille La Verne',
#    'Harry Stockwell',
#    'Roy Atwell',
#    'Pinto Colvig',
#    'Otis Harlan',
#    'Scotty Mattraw',
#    'Billy Gilbert',
#    'Eddie Collins',
# ...

# %% [markdown]
# ### Subtasks
# - ~~clean up references [1]~~
# - ~~convert running time into an integer~~
# - convert dates into datetime object
# - ~~split up the long strings~~
# - ~~convert buget & box office into integers~~

# %%
# clean up the references(remove [1] [2] [3])

# %%
# split up the long strings

# %% [markdown]
# #### convert running time into an integer

# %%
# running time
# loop through the (movie objects) in the list 
# look at the running time value
# movie.get('Running time') instead of movie['Running time'] some movies may lack 'Running time' key
print([movie.get('Running time','N/A') for movie in movie_info_list])
# Out:
# ['41 minutes (74 minutes 1966 release)', '83 minutes', '88 minutes', '126 minutes', '74 minutes', '64 minutes', '70 minutes', '42 minutes', '70 min', '71 minutes', '75 minutes', '94 minutes', '73 minutes', '75 minutes', '82 minutes', '68 minutes', '74 minutes', '96 minutes', '75 minutes', '84 minutes', '77 minutes', '92 minutes', '69 minutes', '81 minutes', ['60 minutes (VHS version)', '71 minutes (original)'], '127 minutes', '92 minutes', '76 minutes', '75 minutes', '73 minutes', '85 minutes', '81 minutes', '70 minutes', '90 min.', '80 minutes', '75 minutes', '83 minutes', '83 minutes', '72 minutes', '97 minutes', '75 minutes', '104 minutes', '93 minutes', '105 minutes', '95 minutes', '97 minutes', '134 minutes', '69 minutes', '92 minutes', '126 minutes', '79 minutes', '97 minutes', '128 minutes', '74 minutes', '91 minutes', '105 minutes', '98 minutes', '130 minutes', '89 min.', '93 minutes', '67 minutes', '98 minutes', '100 minutes', '118 minutes', '103 Minutes', '110 minutes', '80
# ...

# %%
movie_info_list
# Out:
# [{'title': 'Academy Award Review of',
#   'Production company': 'Walt Disney Productions',
#   'Release date': ['May 19, 1937'],
#   'Running time': '41 minutes (74 minutes 1966 release)',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$45.472'},
#  {'title': 'Snow White and the Seven Dwarfs',
#   'Directed by': ['David Hand (supervising)',
#    'William Cottrell',
#    'Wilfred Jackson',
#    'Larry Morey',
#    'Perce Pearce',
#    'Ben Sharpsteen'],
#   'Produced by': 'Walt Disney',
#   'Written by': ['Ted Sears',
#    'Richard Creedon',
#    'Otto Englander',
#    'Dick Rickard',
#    'Earl Hurd',
#    'Merrill De Maris',
#    'Dorothy Ann Blank',
#    'Webb Smith'],
#   'Based on': ['Snow White', 'by The', 'Brothers Grimm'],
#   'Starring': ['Adriana Caselotti',
#    'Lucille La Verne',
#    'Harry Stockwell',
#    'Roy Atwell',
#    'Pinto Colvig',
#    'Otis Harlan',
#    'Scotty Mattraw',
#    'Billy Gilbert',
#    'Eddie Collins',
# ...

# %%
def minutes_to_integer(running_time):
    if running_time == 'N/A': # has no value
        return None
    elif isinstance(running_time,list): # is list
        entry = running_time[0]
        return int(entry.split(' ')[0])
    else: # is string
        return int(running_time.split(' ')[0])

    
# Example
minutes_to_integer('85 minutes')
# Out:
# 85

# %%
minutes_to_integer(['85 minutes','234 minutes'])
# Out:
# 85

# %%
# loop through the movie objects 
# and add a new key 
for movie in movie_info_list:
    movie['Running time (int)'] = minutes_to_integer(movie.get('Running time','N/A'))

# %%
print([movie.get('Running time (int)','N/A') for movie in movie_info_list])
# Out:
# [41, 83, 88, 126, 74, 64, 70, 42, 70, 71, 75, 94, 73, 75, 82, 68, 74, 96, 75, 84, 77, 92, 69, 81, 60, 127, 92, 76, 75, 73, 85, 81, 70, 90, 80, 75, 83, 83, 72, 97, 75, 104, 93, 105, 95, 97, 134, 69, 92, 126, 79, 97, 128, 74, 91, 105, 98, 130, 89, 93, 67, 98, 100, 118, 103, 110, 80, 79, 91, 91, 97, 118, 139, 92, 131, 87, 116, 93, 110, 110, 131, 101, 108, 84, 78, 75, 164, 106, 110, 99, 113, 108, 112, 93, 91, 93, 100, 100, 79, 96, 113, 89, 118, 92, 88, 92, 87, 93, 93, 93, 90, 83, 96, 88, 89, 91, 93, 92, 97, 100, 100, 89, 91, 112, 115, 95, 91, 95, 104, 74, 48, 77, 104, 128, 101, 94, 104, 90, 100, 88, 93, 98, 112, 84, 98, 97, 114, 96, 100, 109, 83, 90, 107, 96, 103, 91, 95, 105, 113, 80, 101, 89, 74, 90, 89, 110, 74, 93, 84, 83, 74, 77, 107, 93, 88, 108, 84, 121, 89, 104, 90, 86, 84, 108, 107, 96, 98, 105, 108, 94, 106, 102, 88, 102, 102, 97, 111, 100, 96, 98, 78, 81, 108, 89, 99, 89, 81, 92, 100, 89, 79, 91, 101, 104, 103, 86, 105, 93, 92, 98, 95, 93, 87, 93, 87, 128, 86, 95, 114, 93, 83,
# ...

# %% [markdown]
# #### convert buget & box office into integers

# %%
([movie.get('Box office','N/A') for movie in movie_info_list])
# Out:
# ['$45.472',
#  '$418 million',
#  '$164 million',
#  '$76.4–$83.3 million',
#  '$960,000 (worldwide rentals)',
#  '$1.3 million (est. United States/Canada rentals, 1941)',
#  '$267.4 million',
#  '$1,135,000 (worldwide rentals)',
#  '$799,000',
#  '$3,355,000 (worldwide rentals)',
#  '$3.275 million (worldwide rentals)',
#  '$65 million',
#  '$3,165,000 (worldwide rentals)',
#  '$2,560,000 (worldwide rentals)',
#  '$3.7 million (U.S. rental) $575,000 (foreign rental)',
#  '$1,625,000 (worldwide rentals)',
#  '$263.6 million',
#  '$4,100,000 (worldwide rentals)',
#  '$5.6 million (US, 1951)',
#  '$2.1 million (US rentals)',
#  '$87.4 million',
#  '$1 million (US)',
#  '$2.6 million (US)',
#  'N/A',
#  '$1.75 million (US and Canadian rentals)',
#  '$28.2 million',
#  '$2,150,000 (US)',
#  '$187 million',
#  '$2.1 million (US)',
#  '$1.6 million (US)',
#  '$1.7 million (US)',
#  'N/A',
#  'N/A',
#  '$2.75 million (US)',
#  'N/A',
#  '$1.75 million (US rentals)',
# ...

# %%
([movie.get('Budget','N/A') for movie in movie_info_list])
# Out:
# ['N/A',
#  '$1.49 million',
#  '$2.6 million',
#  '$2.28 million',
#  '$600,000',
#  '$950,000',
#  '$858,000',
#  'N/A',
#  '$788,000',
#  'N/A',
#  '$1.35 million',
#  '$2.125 million',
#  'N/A',
#  '$1.5 million',
#  '$1.5 million',
#  'N/A',
#  '$2.9 million',
#  '$1,800,000',
#  '$3 million',
#  'N/A',
#  '$4 million',
#  '$2 million',
#  '$300,000',
#  '$1.8 million',
#  'N/A',
#  '$5 million',
#  'N/A',
#  '$4 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$700,000',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$6 million',
#  'under $1 million or $1,250,000',
#  'N/A',
#  '$2 million',
#  'N/A',
#  'N/A',
#  '$2.5 million',
#  'N/A',
#  'N/A',
#  '$4 million',
#  '$3.6 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$3 million',
#  'N/A',
#  '$3 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$3 million',
#  'N/A',
#  'N/A',
#  'N/A',
#  'N/A',
#  '$4.4–6 million',
#  'N/A',
# ...

# %%
# if there is a pattern --> use regex
import re

# money_conversion ('$12.2 million') --> 12200000 ## Word Syntax
# money_conversion ('$790,000') --> 790000 ## VALUE syntax

pattern = r"\d+(,\d{3})*\.*\d*" # pattern is look for (more than one digit)
# + --> one ore more * --> zero or more
amounts = r"thousand|million|billion"
word_re = rf"\${pattern}(-|\sto\s)?({pattern})?\s({amounts})"
value_re = rf"\${pattern}"

def word_to_value(word):
    value_dict = {
        "thousand":1000,
        "million":1000000,
        "billion":1000000000
    }
    
    return value_dict[word]

def parse_word_syntax(string):
    value_string = re.search(pattern,string).group()
    print("Value_string",value_string)
    value = float(value_string.replace(",",""))
    word = re.search(amounts,string,flags=re.I).group().lower()
    word_value = word_to_value(word)
    return value * word_value

def parse_value_syntax(string):
    value_string = re.search(pattern,string).group()
    value = float(value_string.replace(',',""))
    # strip out comma then convertto float 
    return value    

def money_conversion(money):
    print('money:',money)
    if money == 'N/A':
        return None
    # if list grab first element as the money string
    if isinstance(money,list):
        money = money[0]
    # has $ infront of it 
    word_syntax = re.search(word_re,money)
    value_syntax = re.search(value_re,money)
    # if it follows $digits million or thousand or billion
    if word_syntax:
        return parse_word_syntax(word_syntax.group())
        
    elif value_syntax:
        return parse_value_syntax(value_syntax.group())
    else:
        return None


# .group() tells what match it is 
#print(re.search(pattern,'234,345.5').group()) # pass the pattern (number) & text you want to serch for pattern ie "123"

# %%
print(re.search(word_re,"$12.2 million").group())
# Out:
# $12.2 million

# %%
print(money_conversion("$12.2"))
# Out:
# money: $12.2
# 12.2

# %%
print(money_conversion("$12.2 billion"))
# Out:
# money: $12.2 billion
# Value_string 12.2
# 12200000000.0

# %%
print(money_conversion("['$306.6 million (gross)', '$263.7 million (net)']"))
# Out:
# money: ['$306.6 million (gross)', '$263.7 million (net)']
# Value_string 306.6
# 306600000.0

# %%
print(money_conversion( '$36 –39.6 million'))
# Out:
# money: $36 –39.6 million
# 36.0

# %%
money_conversion('$790,000.9789')
# Out:
# money: $790,000.9789
# 790000.9789

# %%
for movie in movie_info_list:
    movie['Budget (float)'] = money_conversion(movie.get('Budget','N/A'))
    movie['Box office (float)'] = money_conversion(movie.get('Box office','N/A'))
# Out:
# money: N/A
# money: $45.472
# money: $1.49 million
# Value_string 1.49
# money: $418 million
# Value_string 418
# money: $2.6 million
# Value_string 2.6
# money: $164 million
# Value_string 164
# money: $2.28 million
# Value_string 2.28
# money: $76.4–$83.3 million
# Value_string 83.3
# money: $600,000
# money: $960,000 (worldwide rentals)
# money: $950,000
# money: $1.3 million (est. United States/Canada rentals, 1941)
# Value_string 1.3
# money: $858,000
# money: $267.4 million
# Value_string 267.4
# money: N/A
# money: $1,135,000 (worldwide rentals)
# money: $788,000
# money: $799,000
# money: N/A
# money: $3,355,000 (worldwide rentals)
# money: $1.35 million
# Value_string 1.35
# money: $3.275 million (worldwide rentals)
# Value_string 3.275
# money: $2.125 million
# Value_string 2.125
# money: $65 million
# Value_string 65
# money: N/A
# money: $3,165,000 (worldwide rentals)
# money: $1.5 million
# Value_string 1.5
# money: $2,560,000 (worldwide rentals)
# money: $1.5 million
# ...

# %%
money_conversion('$160-254 million')
# Out:
# money: $160-254 million
# Value_string 160
# 160000000.0

# %% [markdown]
# ### Convert Dates to Datetime Objects

# %%
([movie.get('Release date','N/A') for movie in movie_info_list])
# Out:
# [['May 19, 1937'],
#  ['December 21, 1937 ( Carthay Circle Theatre , Los Angeles , CA , premiere)'],
#  ['February 7, 1940 ( Center Theatre )', 'February 23, 1940 (United States)'],
#  ['November 13, 1940'],
#  ['June 27, 1941'],
#  ['October 23, 1941 (New York City)', 'October 31, 1941 (U.S.)'],
#  ['August 9, 1942 (World Premiere-London)',
#   'August 13, 1942 (Premiere-New York City)',
#   'August 21, 1942 (U.S.)'],
#  ['August 24, 1942 (World Premiere-Rio de Janeiro)',
#   'February 6, 1943 (U.S. Premiere-Boston)',
#   'February 19, 1943 (U.S.)'],
#  ['July 17, 1943'],
#  ['December 21, 1944 (Mexico City)', 'February 3, 1945 (US)'],
#  ['April 20, 1946 (New York City premiere)', 'August 15, 1946 (U.S.)'],
#  ['November 12, 1946 (Premiere: Atlanta, Georgia)',
#   'November 20, 1946',
#   'March 30, 1947 (Stanford Theatre, Palo Alto, California)'],
#  ['September 27, 1947'],
#  'May 27, 1948',
#  ['November 29, 1948 (Chicago, Illinois)',
# ...

# %%
# june 28 1950
from datetime import datetime
# release dates for each movie object
dates = [movie.get('Release date','N/A') for movie in movie_info_list]

def clean_date(date):
    return date.split("(")[0].strip()
    

def date_conversion(date):
    if isinstance(date,list):
        date = date[0]
    if date == 'N/A':
        return None
    date_str = clean_date(date)
    #print(date_str)
    
    fmts = ["%B %d, %Y","%d %B %Y"]
    
    for fmt in fmts:
        try:
            return datetime.strptime(date_str,fmt)
        except:
            pass
    return None
    
    
    
for date in dates:
    print(date_conversion(date))
# Out:
# 1937-05-19 00:00:00
# 1937-12-21 00:00:00
# 1940-02-07 00:00:00
# 1940-11-13 00:00:00
# 1941-06-27 00:00:00
# 1941-10-23 00:00:00
# 1942-08-09 00:00:00
# 1942-08-24 00:00:00
# 1943-07-17 00:00:00
# 1944-12-21 00:00:00
# 1946-04-20 00:00:00
# 1946-11-12 00:00:00
# 1947-09-27 00:00:00
# 1948-05-27 00:00:00
# 1948-11-29 00:00:00
# 1949-10-05 00:00:00
# 1950-02-15 00:00:00
# 1950-06-22 00:00:00
# 1951-07-26 00:00:00
# 1952-03-13 00:00:00
# 1953-02-05 00:00:00
# 1953-07-23 00:00:00
# 1953-11-10 00:00:00
# 1953-10-26 00:00:00
# 1954-08-17 00:00:00
# 1954-12-23 00:00:00
# 1955-05-25 00:00:00
# 1955-06-22 00:00:00
# 1955-09-14 00:00:00
# 1955-12-22 00:00:00
# 1956-06-08 00:00:00
# 1956-07-18 00:00:00
# 1956-09-04 00:00:00
# 1956-12-20 00:00:00
# 1957-06-19 00:00:00
# 1957-08-28 00:00:00
# 1957-12-25 00:00:00
# 1958-07-08 00:00:00
# 1958-08-12 00:00:00
# 1958-12-25 00:00:00
# 1959-01-29 00:00:00
# 1959-03-19 00:00:00
# 1959-06-24 00:00:00
# 1959-11-10 00:00:00
# 1960-01-21 00:00:00
# ...

# %%
for movie in movie_info_list:
    movie["Release date (datetime)"] = date_conversion(movie.get('Release date','N/A'))

# %%
import pickle

def save_data_pickle(name,data):
    with open (name,'wb') as f: # open the file 
        pickle.dump(data,f) # save data in it

# %%
import pickle
def load_data_pickle(name):
    with open(name,'rb') as f:
        return pickle.load(f)

# %%
save_data_pickle('disney_data_more_clean.pickle',movie_info_list)

# %%
data = load_data_pickle('disney_data_more_clean.pickle')
data
# Out:
# [{'title': 'Academy Award Review of',
#   'Production company': 'Walt Disney Productions',
#   'Release date': ['May 19, 1937'],
#   'Running time': '41 minutes (74 minutes 1966 release)',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$45.472',
#   'Running time (int)': 41,
#   'Budget (float)': None,
#   'Box office (float)': 45.472,
#   'Release date (datetime)': datetime.datetime(1937, 5, 19, 0, 0)},
#  {'title': 'Snow White and the Seven Dwarfs',
#   'Directed by': ['David Hand (supervising)',
#    'William Cottrell',
#    'Wilfred Jackson',
#    'Larry Morey',
#    'Perce Pearce',
#    'Ben Sharpsteen'],
#   'Produced by': 'Walt Disney',
#   'Written by': ['Ted Sears',
#    'Richard Creedon',
#    'Otto Englander',
#    'Dick Rickard',
#    'Earl Hurd',
#    'Merrill De Maris',
#    'Dorothy Ann Blank',
#    'Webb Smith'],
#   'Based on': ['Snow White', 'by The', 'Brothers Grimm'],
#   'Starring': ['Adriana Caselotti',
#    'Lucille La Verne',
# ...

# %%
data == movie_info_list
# Out:
# True

# %% [markdown]
# ### Attach IMDB/Rotten Tomatoes/Metascores scores

# %%
movie_info_list = load_data_pickle("disney_data_more_clean.pickle")
movie_info_list
# Out:
# [{'title': 'Academy Award Review of',
#   'Production company': 'Walt Disney Productions',
#   'Release date': ['May 19, 1937'],
#   'Running time': '41 minutes (74 minutes 1966 release)',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$45.472',
#   'Running time (int)': 41,
#   'Budget (float)': None,
#   'Box office (float)': 45.472,
#   'Release date (datetime)': datetime.datetime(1937, 5, 19, 0, 0)},
#  {'title': 'Snow White and the Seven Dwarfs',
#   'Directed by': ['David Hand (supervising)',
#    'William Cottrell',
#    'Wilfred Jackson',
#    'Larry Morey',
#    'Perce Pearce',
#    'Ben Sharpsteen'],
#   'Produced by': 'Walt Disney',
#   'Written by': ['Ted Sears',
#    'Richard Creedon',
#    'Otto Englander',
#    'Dick Rickard',
#    'Earl Hurd',
#    'Merrill De Maris',
#    'Dorothy Ann Blank',
#    'Webb Smith'],
#   'Based on': ['Snow White', 'by The', 'Brothers Grimm'],
#   'Starring': ['Adriana Caselotti',
#    'Lucille La Verne',
# ...

# %%
# OMDB API to get other movie data like 
# Ratings 

import requests
import urllib # encode parameteres onto the url

# %%
def get_rotten_tomato_score(omdb_info):
    ratings = omdb_info.get('Rating',[])
    for rating in ratings:
        if rating['Source'] == "Rotten Tomatoes":
            return rating['Value']
    return None
def get_omdb_info(title):
    base_url = "http://www.omdbapi.com/"
    parameters = {
        "apikey":"sthsth",
        "t":title
        }
    params_encoded = urllib.parse.urlencode(parameters)
    full_url = base_url + params_encoded
    return requests.get(full_url).json()

# %%
#testing
get_omdb_info("into the woods")

# %%
for movie in movie_info_list:
    title = movie['title']
    omdb_info = get_omdb_info(title)
    movie['info'] = omdb_info.get('imdbRating',None)
    movie['metascore'] = omdb_info.get('Metascore')
    movie['rotten_tomatoes'] = get_rotten_tomato_score(omdb_info)

# %%
movie_info_list

# %% [markdown]
# ### save to json & csv

# %%
movie_info_copy = [movie.copy() for movie in movie_info_list]

# %%
# edit the movie release date 
for movie in movie_info_copy:
    current_date = movie['Release date (datetime)']
    if current_date:
        movie['Release date (datetime)']  = current_date.strftime("%B %d,%Y")
    else:
        movie['Release date (datetime)'] = None

# %%
save_data("disney_data_final.json",movie_info_copy)

# %%
# to cvs
import pandas as pd 
# load list of objects to pandas
df =pd.DataFrame(movie_info_list)
df.to_csv("disney_movie_data_final.csv")
